# %%
def three_end_mapping(samgen,GFFgen_filename):
    from BCBio import GFF
    from Bio import Seq
    outputdata1={}
    outputdata2={}
    GFFgen=GFF.parse(GFFgen_filename)
    for sequence in GFFgen:
        outputdata1[sequence.id]=[0 for x in range(len(sequence))]
        outputdata2[sequence.id]=[0 for x in range(len(sequence))]
        for read in samgen:
            if read[0][0] == '@':   # Ignore header lines.
                continue
            if read[1] == '4':      # A bowtie mismatch. These are the same as those previously saved in the files bowtie output as reads without matches and reads exceeding the -m limit. No need to write as fastq.
                continue            
            chrom = read[2]             # chromosome identified for read in bowtie
            readid = read[0]            # read id
            startp = int(read[3]) - 1    # start position. Need to subtract 1 since genomic sequence starts at 1, but list structures for read summing start at 0.
            seq = Seq.Seq(read[9])      # sequence of the read
            length = len(seq)           # length of read
            if (read[1] == '16'):
                start = startp
                outputdata2[chrom][start] += 1
            if (read[1] == '0'):
                start = startp + length - 1
                outputdata1[chrom][start] += 1
    return [outputdata1,outputdata2]  

def readcounts_to_rpm(readcounts):
    for chrom in readcounts.keys():
        totalread = sum(readcounts[chrom])
        for position in range(len(readcounts[chrom])):
            readcounts[chrom][position]/=float(totalread)
            readcounts[chrom][position]*=1E6

# makes density file 
# the last letter "f" in writecountsf means float
def writecountsf(rpm,filepath):  #Resultlist it is the list of counts, filestring is the file prefix for each chr to be written.
    import struct
    f2=open(filepath+"keys","w")
    for chrom in rpm.keys():
        f=open(filepath+"genome","wb")
        # used to be (filepath+chrom,"wb") but server fail to show a file with a name containing "|"
        # rename "genome" to real genome name manually 
        for position in rpm[chrom]:
            f.write(struct.pack("f",position))
            # struct.pack to make binary based on the format indicated 
            # here, the indication of format is "f", which means float
        f.close()
        f2.write(chrom+"\n")
    f2.close()

# makes wig file
def countstowig(rpm,filestring):
    import random
    f=open(filestring+".wig","w")
    filestring=filestring.partition("_")[0][-3:]

    random.seed(filestring)
    c1=random.randint(0,255)
    random.seed(filestring+"xxx")
    c2=random.randint(0,255)
    random.seed(filestring+"000")
    c3=random.randint(0,255)

    f.write("track name=tracklabel viewLimits=-5:5 color="+str(c1)+','+str(c2)+','+str(c3)+"\n")
    for chrom in rpm.keys():
        if chrom[0:3]=='chr':
            f.write("fixedStep  chrom="+chrom+"  start=1  step=1\n")
        else:
            f.write("fixedStep  chrom=\""+chrom+"\"  start=1  step=1\n")	# Note the extra '' around chrom added for E coli. Should be fine for yeast. Actually it's not. So new code here to detect that.


        for position in rpm[chrom]:
            f.write(str(position)+"\n")
    f.close()

# %%
fastq_path = '/home/kazuki/^profilingdata/20160420/'
filepath = '/home/kazuki/^profilingdata/20160420_reanalyze/'
files = ['ks'+str(x) for x in range(5,23)]
bowtie_input_extension = '-trimmed.fastq'
mapping = '_3map'
gene_type = '_gene'

# %%
######################################################
from datetime import datetime
import os

skewer = '/home/kazuki/^data_analysis/analtools/skewer022/skewer-0.2.2-linux-x86_64'
option = '-Q 10'
adapter = 'CTGTAGGCACCATCAAT'

log_file = filepath+'log_skewer.txt'
###
logs = open(log_file, 'w')
present = str(datetime.now())
logs.write(present+'\n')
logs.close()
###


for f in files:
    print 'skewer for ' + f
    file_path = filepath+f+'.fastq'
    
    command = '%s %s -x %s %s >> %s' % (
        skewer,
        option,
        adapter,
        file_path,
        log_file
        ) 
    
    os.system(command)
    
print 
print 
for line in open(log_file, 'r'):
    print line[:-1]
# Out:
# skewer for ks5
# skewer for ks6
# skewer for ks7
# skewer for ks8
# skewer for ks9
# skewer for ks10
# skewer for ks11
# skewer for ks12
# skewer for ks13
# skewer for ks14
# skewer for ks15
# skewer for ks16
# skewer for ks17
# skewer for ks18
# skewer for ks19
# skewer for ks20
# skewer for ks21
# skewer for ks22
#
#
# 2019-06-03 09:25:25.448889
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:25:25 2019 >> started
#
# Mon Jun  3 09:26:04 2019 >> done (39.127s)
# 18495146 reads processed; of these:
#     6792 ( 0.04%) reads filtered out by quality control
#  3368864 (18.21%) short reads filtered out after trimming by size control
#   698639 ( 3.78%) empty reads filtered out after trimming by size control
# 14420851 (77.97%) reads available; of these:
# 13719122 (95.13%) trimmed reads available after processing
#   701729 ( 4.87%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks5-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:26:04 2019 >> started
#
# Mon Jun  3 09:26:25 2019 >> done (21.167s)
# 9760065 reads processed; of these:
#    3053 ( 0.03%) reads filtered out by quality control
# 1827359 (18.72%) short reads filtered out after trimming by size control
#  562038 ( 5.76%) empty reads filtered out after trimming by size control
# 7367615 (75.49%) reads available; of these:
# 6975711 (94.68%) trimmed reads available after processing
#  391904 ( 5.32%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks6-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:26:25 2019 >> started
#
# Mon Jun  3 09:26:52 2019 >> done (26.943s)
# 12609432 reads processed; of these:
#     5197 ( 0.04%) reads filtered out by quality control
#  2303504 (18.27%) short reads filtered out after trimming by size control
#  1614786 (12.81%) empty reads filtered out after trimming by size control
#  8685945 (68.88%) reads available; of these:
#  8082723 (93.06%) trimmed reads available after processing
#   603222 ( 6.94%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks7-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:26:52 2019 >> started
#
# Mon Jun  3 09:27:04 2019 >> done (11.437s)
# 5059808 reads processed; of these:
#    2009 ( 0.04%) reads filtered out by quality control
# 1043260 (20.62%) short reads filtered out after trimming by size control
#  373471 ( 7.38%) empty reads filtered out after trimming by size control
# 3641068 (71.96%) reads available; of these:
# 3413788 (93.76%) trimmed reads available after processing
#  227280 ( 6.24%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks8-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:27:04 2019 >> started
#
# Mon Jun  3 09:27:39 2019 >> done (35.372s)
# 16621487 reads processed; of these:
#     6432 ( 0.04%) reads filtered out by quality control
#  3149571 (18.95%) short reads filtered out after trimming by size control
#  1157505 ( 6.96%) empty reads filtered out after trimming by size control
# 12307979 (74.05%) reads available; of these:
# 11617910 (94.39%) trimmed reads available after processing
#   690069 ( 5.61%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks9-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:27:39 2019 >> started
#
# Mon Jun  3 09:28:16 2019 >> done (36.937s)
# 17381575 reads processed; of these:
#     5710 ( 0.03%) reads filtered out by quality control
#  4065895 (23.39%) short reads filtered out after trimming by size control
#   893984 ( 5.14%) empty reads filtered out after trimming by size control
# 12415986 (71.43%) reads available; of these:
# 11750195 (94.64%) trimmed reads available after processing
#   665791 ( 5.36%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks10-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:28:16 2019 >> started
#
# Mon Jun  3 09:29:38 2019 >> done (82.373s)
# 41304153 reads processed; of these:
#    13154 ( 0.03%) reads filtered out by quality control
# 17156550 (41.54%) short reads filtered out after trimming by size control
#  6194830 (15.00%) empty reads filtered out after trimming by size control
# 17939619 (43.43%) reads available; of these:
# 15906256 (88.67%) trimmed reads available after processing
#  2033363 (11.33%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks11-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:29:38 2019 >> started
#
# Mon Jun  3 09:30:41 2019 >> done (62.921s)
# 30678414 reads processed; of these:
#    10335 ( 0.03%) reads filtered out by quality control
#  9860359 (32.14%) short reads filtered out after trimming by size control
#  3093234 (10.08%) empty reads filtered out after trimming by size control
# 17714486 (57.74%) reads available; of these:
# 16354514 (92.32%) trimmed reads available after processing
#  1359972 ( 7.68%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks12-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:30:41 2019 >> started
#
# Mon Jun  3 09:31:33 2019 >> done (51.535s)
# 24678394 reads processed; of these:
#     8437 ( 0.03%) reads filtered out by quality control
#  6583667 (26.68%) short reads filtered out after trimming by size control
#  2230908 ( 9.04%) empty reads filtered out after trimming by size control
# 15855382 (64.25%) reads available; of these:
# 14830262 (93.53%) trimmed reads available after processing
#  1025120 ( 6.47%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks13-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:31:33 2019 >> started
#
# Mon Jun  3 09:31:59 2019 >> done (26.253s)
# 12378224 reads processed; of these:
#     4213 ( 0.03%) reads filtered out by quality control
#  3556450 (28.73%) short reads filtered out after trimming by size control
#   986644 ( 7.97%) empty reads filtered out after trimming by size control
#  7830917 (63.26%) reads available; of these:
#  7253761 (92.63%) trimmed reads available after processing
#   577156 ( 7.37%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks14-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:31:59 2019 >> started
#
# Mon Jun  3 09:32:37 2019 >> done (37.560s)
# 17780946 reads processed; of these:
#     6189 ( 0.03%) reads filtered out by quality control
#  4904953 (27.59%) short reads filtered out after trimming by size control
#  1489916 ( 8.38%) empty reads filtered out after trimming by size control
# 11379888 (64.00%) reads available; of these:
# 10631422 (93.42%) trimmed reads available after processing
#   748466 ( 6.58%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks15-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:32:37 2019 >> started
#
# Mon Jun  3 09:33:27 2019 >> done (50.087s)
# 23717958 reads processed; of these:
#     8159 ( 0.03%) reads filtered out by quality control
#  7738766 (32.63%) short reads filtered out after trimming by size control
#   896089 ( 3.78%) empty reads filtered out after trimming by size control
# 15074944 (63.56%) reads available; of these:
# 14182803 (94.08%) trimmed reads available after processing
#   892141 ( 5.92%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks16-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:33:27 2019 >> started
#
# Mon Jun  3 09:34:04 2019 >> done (37.531s)
# 17213917 reads processed; of these:
#     4873 ( 0.03%) reads filtered out by quality control
#  4158526 (24.16%) short reads filtered out after trimming by size control
#    10130 ( 0.06%) empty reads filtered out after trimming by size control
# 13040388 (75.75%) reads available; of these:
# 12304152 (94.35%) trimmed reads available after processing
#   736236 ( 5.65%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks17-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:34:04 2019 >> started
#
# Mon Jun  3 09:34:36 2019 >> done (31.950s)
# 14684178 reads processed; of these:
#     3970 ( 0.03%) reads filtered out by quality control
#  3464770 (23.60%) short reads filtered out after trimming by size control
#    12774 ( 0.09%) empty reads filtered out after trimming by size control
# 11202664 (76.29%) reads available; of these:
# 10546912 (94.15%) trimmed reads available after processing
#   655752 ( 5.85%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks18-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:34:36 2019 >> started
#
# Mon Jun  3 09:35:25 2019 >> done (49.220s)
# 22985988 reads processed; of these:
#     6469 ( 0.03%) reads filtered out by quality control
#  6133679 (26.68%) short reads filtered out after trimming by size control
#    35248 ( 0.15%) empty reads filtered out after trimming by size control
# 16810592 (73.13%) reads available; of these:
# 15748798 (93.68%) trimmed reads available after processing
#  1061794 ( 6.32%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks19-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:35:25 2019 >> started
#
# Mon Jun  3 09:36:03 2019 >> done (37.800s)
# 17526813 reads processed; of these:
#     5118 ( 0.03%) reads filtered out by quality control
#  6076220 (34.67%) short reads filtered out after trimming by size control
#    18968 ( 0.11%) empty reads filtered out after trimming by size control
# 11426507 (65.19%) reads available; of these:
# 10666428 (93.35%) trimmed reads available after processing
#   760079 ( 6.65%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks20-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:36:03 2019 >> started
#
# Mon Jun  3 09:36:41 2019 >> done (37.496s)
# 18357760 reads processed; of these:
#     5162 ( 0.03%) reads filtered out by quality control
# 10135527 (55.21%) short reads filtered out after trimming by size control
#   114160 ( 0.62%) empty reads filtered out after trimming by size control
#  8102911 (44.14%) reads available; of these:
#  7448056 (91.92%) trimmed reads available after processing
#   654855 ( 8.08%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks21-trimmed.log".
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	CTGTAGGCACCATCAAT
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- mean quality threshold (-Q):		10
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- minimum overlap length for adapter detection (-k):	3
# Mon Jun  3 09:36:41 2019 >> started
#
# Mon Jun  3 09:37:13 2019 >> done (31.962s)
# 15739277 reads processed; of these:
#     4674 ( 0.03%) reads filtered out by quality control
#  9072391 (57.64%) short reads filtered out after trimming by size control
#   102335 ( 0.65%) empty reads filtered out after trimming by size control
#  6559877 (41.68%) reads available; of these:
#  6025409 (91.85%) trimmed reads available after processing
#   534468 ( 8.15%) untrimmed reads available after processing
# log has been saved to "/home/kazuki/^profilingdata/20160420_reanalyze/ks22-trimmed.log".

# %%
######################################################
######################################################
from datetime import datetime
import os

inpath = filepath
outpath = filepath

log_file = inpath+'log_bowtie_ks48.txt'
###
logs = open(log_file, 'w')
present = str(datetime.now())
logs.write(present+'\n')
logs.close()
###

path_l = outpath + 'alignments/ladder/'
path_t = outpath + 'alignments/tRNA/'
path_r = outpath + 'alignments/rRNA/'
path_chr = outpath + 'alignments/chr/'
path_temp = outpath + 'tmpds/'

if not os.path.exists(path_l):
    os.makedirs(path_l)
if not os.path.exists(path_t):
    os.makedirs(path_t)
if not os.path.exists(path_r):
    os.makedirs(path_r)
if not os.path.exists(path_chr):
    os.makedirs(path_chr)
if not os.path.exists(path_temp):
    os.makedirs(path_temp)
    #print 'really? there is no tmpds folder?'

    ###uses bowtie installed in server
for fname in files:
    print fname

    bowtie_command = 'bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 '\
        '--un %s%s --max %s%s --al %s%s %s %s%s %s%s 1>> %s 2>> %s'
        # The `--strata` and `--best` options do not apply in paired-end mode.
        # Paired-end alignments where one mate's alignment is entirely contained within the other's are considered invalid.

        
        # first, align to ladder index to subtract any ladder oligos that were cloned        
    bowtie_ladder = bowtie_command %(
        path_l,
        fname+'_nomatch.fastq',
        path_l,
        fname+'_multi.fastq',
        path_l,
        fname+'_match.fastq',
        '/home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder',
        inpath,
        fname + bowtie_input_extension,
        path_temp,
        fname + '_ladder_match.SAM',
        log_file,
        log_file
        )
    ###
    logs = open(log_file, 'a+')
    logs.write('\n\n'+fname+'\n'+bowtie_ladder+'\n')
    logs.close()
    ###
    os.system(bowtie_ladder)        
        
        
        # second, align to tRNA index
    bowtie_tRNA = bowtie_command %(
        path_t,
        fname+'_nomatch.fastq',
        path_t,
        fname+'_multi.fastq',
        path_t,
        fname+'_match.fastq',
        '/home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA',
        path_l,
        fname +'_nomatch.fastq',
        path_temp,
        fname + '_tRNA_match.SAM',
        log_file,
        log_file
        )
    ###
    logs = open(log_file, 'a+')
    logs.write('\n'+bowtie_tRNA+'\n')
    logs.close()
    ###
    os.system(bowtie_tRNA)        
        
        
        # third, align to the rRNA index
    bowtie_rRNA = bowtie_command %(
        path_r,
        fname+'_nomatch.fastq',
        path_r,
        fname+'_multi.fastq',
        path_r,
        fname+'_match.fastq',
        '/home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655',
        path_t,
        fname +'_nomatch.fastq',
        path_temp,
        fname + '_rRNA_match.SAM',
        log_file,
        log_file
        )
    ###
    logs = open(log_file, 'a+')
    logs.write('\n'+bowtie_rRNA+'\n')
    logs.close()
    ###
    os.system(bowtie_rRNA)         
        
        # finally align to the chr index
    bowtie_chr = bowtie_command %(
        path_chr,
        fname+'_nomatch.fastq',
        path_chr,
        fname+'_multi.fastq',
        path_chr,
        fname+'_match.fastq',
        '/home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655',
        path_r,
        fname +'_nomatch.fastq',
        path_chr,
        fname + '_match.SAM',
        log_file,
        log_file
        )
    ###
    logs = open(log_file, 'a+')
    logs.write('\n'+bowtie_chr+'\n')
    logs.close()
    ###
    os.system(bowtie_chr)
    

logs = open(log_file, 'a+')
present = str(datetime.now())
logs.write('\n'+present+'\n')
logs.close()
    
print 
print 
for line in open(log_file, 'r'):
    print line[:-1]
# Out:
# ks5
# ks6
# ks7
# ks8
# ks9
# ks10
# ks11
# ks12
# ks13
# ks14
# ks15
# ks16
# ks17
# ks18
# ks19
# ks20
# ks21
# ks22
#
#
# 2019-06-03 09:37:13.393750
#
#
# ks5
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks5_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks5_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks5_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks5-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks5_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 14420851
# # reads with at least one reported alignment: 58816 (0.41%)
# # reads that failed to align: 14352580 (99.53%)
# # reads with alignments suppressed due to -m: 9455 (0.07%)
# Reported 58816 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks5_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks5_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks5_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks5_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks5_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 14352580
# # reads with at least one reported alignment: 1665557 (11.60%)
# # reads that failed to align: 7885336 (54.94%)
# # reads with alignments suppressed due to -m: 4801687 (33.46%)
# Reported 1665557 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks5_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks5_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks5_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks5_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks5_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 7885336
# # reads with at least one reported alignment: 10350 (0.13%)
# # reads that failed to align: 6574712 (83.38%)
# # reads with alignments suppressed due to -m: 1300274 (16.49%)
# Reported 10350 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks5_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks5_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks5_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks5_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks5_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 6574712
# # reads with at least one reported alignment: 5236460 (79.65%)
# # reads that failed to align: 1207162 (18.36%)
# # reads with alignments suppressed due to -m: 131090 (1.99%)
# Reported 5236460 alignments to 1 output stream(s)
#
#
# ks6
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks6_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks6_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks6_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks6-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks6_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 7367615
# # reads with at least one reported alignment: 11889 (0.16%)
# # reads that failed to align: 7353758 (99.81%)
# # reads with alignments suppressed due to -m: 1968 (0.03%)
# Reported 11889 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks6_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks6_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks6_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks6_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks6_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 7353758
# # reads with at least one reported alignment: 827529 (11.25%)
# # reads that failed to align: 3973260 (54.03%)
# # reads with alignments suppressed due to -m: 2552969 (34.72%)
# Reported 827529 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks6_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks6_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks6_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks6_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks6_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3973260
# # reads with at least one reported alignment: 5824 (0.15%)
# # reads that failed to align: 3446413 (86.74%)
# # reads with alignments suppressed due to -m: 521023 (13.11%)
# Reported 5824 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks6_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks6_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks6_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks6_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks6_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3446413
# # reads with at least one reported alignment: 2790468 (80.97%)
# # reads that failed to align: 586470 (17.02%)
# # reads with alignments suppressed due to -m: 69475 (2.02%)
# Reported 2790468 alignments to 1 output stream(s)
#
#
# ks7
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks7_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks7_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks7_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks7-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks7_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 8685945
# # reads with at least one reported alignment: 19476 (0.22%)
# # reads that failed to align: 8663253 (99.74%)
# # reads with alignments suppressed due to -m: 3216 (0.04%)
# Reported 19476 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks7_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks7_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks7_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks7_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks7_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 8663253
# # reads with at least one reported alignment: 1136404 (13.12%)
# # reads that failed to align: 4415242 (50.97%)
# # reads with alignments suppressed due to -m: 3111607 (35.92%)
# Reported 1136404 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks7_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks7_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks7_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks7_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks7_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 4415242
# # reads with at least one reported alignment: 5944 (0.13%)
# # reads that failed to align: 3978334 (90.10%)
# # reads with alignments suppressed due to -m: 430964 (9.76%)
# Reported 5944 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks7_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks7_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks7_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks7_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks7_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3978334
# # reads with at least one reported alignment: 3104436 (78.03%)
# # reads that failed to align: 796803 (20.03%)
# # reads with alignments suppressed due to -m: 77095 (1.94%)
# Reported 3104436 alignments to 1 output stream(s)
#
#
# ks8
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks8_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks8_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks8_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks8-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks8_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3641068
# # reads with at least one reported alignment: 7124 (0.20%)
# # reads that failed to align: 3632826 (99.77%)
# # reads with alignments suppressed due to -m: 1118 (0.03%)
# Reported 7124 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks8_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks8_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks8_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks8_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks8_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3632826
# # reads with at least one reported alignment: 639912 (17.61%)
# # reads that failed to align: 1540222 (42.40%)
# # reads with alignments suppressed due to -m: 1452692 (39.99%)
# Reported 639912 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks8_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks8_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks8_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks8_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks8_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 1540222
# # reads with at least one reported alignment: 2853 (0.19%)
# # reads that failed to align: 1305673 (84.77%)
# # reads with alignments suppressed due to -m: 231696 (15.04%)
# Reported 2853 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks8_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks8_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks8_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks8_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks8_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 1305673
# # reads with at least one reported alignment: 968560 (74.18%)
# # reads that failed to align: 315401 (24.16%)
# # reads with alignments suppressed due to -m: 21712 (1.66%)
# Reported 968560 alignments to 1 output stream(s)
#
#
# ks9
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks9_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks9_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks9_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks9-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks9_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 12307979
# # reads with at least one reported alignment: 28436 (0.23%)
# # reads that failed to align: 12274422 (99.73%)
# # reads with alignments suppressed due to -m: 5121 (0.04%)
# Reported 28436 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks9_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks9_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks9_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks9_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks9_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 12274422
# # reads with at least one reported alignment: 1956650 (15.94%)
# # reads that failed to align: 4793495 (39.05%)
# # reads with alignments suppressed due to -m: 5524277 (45.01%)
# Reported 1956650 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks9_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks9_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks9_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks9_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks9_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 4793495
# # reads with at least one reported alignment: 9753 (0.20%)
# # reads that failed to align: 3907882 (81.52%)
# # reads with alignments suppressed due to -m: 875860 (18.27%)
# Reported 9753 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks9_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks9_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks9_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks9_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks9_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3907882
# # reads with at least one reported alignment: 2824859 (72.29%)
# # reads that failed to align: 1024884 (26.23%)
# # reads with alignments suppressed due to -m: 58139 (1.49%)
# Reported 2824859 alignments to 1 output stream(s)
#
#
# ks10
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks10_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks10_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks10_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks10-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks10_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 12415986
# # reads with at least one reported alignment: 50968 (0.41%)
# # reads that failed to align: 12357397 (99.53%)
# # reads with alignments suppressed due to -m: 7621 (0.06%)
# Reported 50968 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks10_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks10_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks10_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks10_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks10_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 12357397
# # reads with at least one reported alignment: 2502949 (20.25%)
# # reads that failed to align: 3490938 (28.25%)
# # reads with alignments suppressed due to -m: 6363510 (51.50%)
# Reported 2502949 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks10_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks10_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks10_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks10_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks10_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3490938
# # reads with at least one reported alignment: 15012 (0.43%)
# # reads that failed to align: 2710482 (77.64%)
# # reads with alignments suppressed due to -m: 765444 (21.93%)
# Reported 15012 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks10_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks10_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks10_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks10_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks10_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 2710482
# # reads with at least one reported alignment: 1753276 (64.69%)
# # reads that failed to align: 917658 (33.86%)
# # reads with alignments suppressed due to -m: 39548 (1.46%)
# Reported 1753276 alignments to 1 output stream(s)
#
#
# ks11
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks11_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks11_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks11_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks11-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks11_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 17939619
# # reads with at least one reported alignment: 581639 (3.24%)
# # reads that failed to align: 17293380 (96.40%)
# # reads with alignments suppressed due to -m: 64600 (0.36%)
# Reported 581639 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks11_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks11_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks11_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks11_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks11_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 17293380
# # reads with at least one reported alignment: 357587 (2.07%)
# # reads that failed to align: 16340345 (94.49%)
# # reads with alignments suppressed due to -m: 595448 (3.44%)
# Reported 357587 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks11_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks11_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks11_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks11_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks11_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 16340345
# # reads with at least one reported alignment: 30003 (0.18%)
# # reads that failed to align: 14666742 (89.76%)
# # reads with alignments suppressed due to -m: 1643600 (10.06%)
# Reported 30003 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks11_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks11_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks11_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks11_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks11_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 14666742
# # reads with at least one reported alignment: 11686555 (79.68%)
# # reads that failed to align: 2567355 (17.50%)
# # reads with alignments suppressed due to -m: 412832 (2.81%)
# Reported 11686555 alignments to 1 output stream(s)
#
#
# ks12
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks12_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks12_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks12_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks12-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks12_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 17714486
# # reads with at least one reported alignment: 101561 (0.57%)
# # reads that failed to align: 17597227 (99.34%)
# # reads with alignments suppressed due to -m: 15698 (0.09%)
# Reported 101561 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks12_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks12_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks12_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks12_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks12_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 17597227
# # reads with at least one reported alignment: 410495 (2.33%)
# # reads that failed to align: 16443969 (93.45%)
# # reads with alignments suppressed due to -m: 742763 (4.22%)
# Reported 410495 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks12_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks12_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks12_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks12_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks12_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 16443969
# # reads with at least one reported alignment: 33545 (0.20%)
# # reads that failed to align: 14420717 (87.70%)
# # reads with alignments suppressed due to -m: 1989707 (12.10%)
# Reported 33545 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks12_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks12_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks12_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks12_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks12_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 14420717
# # reads with at least one reported alignment: 12052268 (83.58%)
# # reads that failed to align: 1950319 (13.52%)
# # reads with alignments suppressed due to -m: 418130 (2.90%)
# Reported 12052268 alignments to 1 output stream(s)
#
#
# ks13
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks13_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks13_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks13_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks13-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks13_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 15855382
# # reads with at least one reported alignment: 56177 (0.35%)
# # reads that failed to align: 15790550 (99.59%)
# # reads with alignments suppressed due to -m: 8655 (0.05%)
# Reported 56177 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks13_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks13_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks13_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks13_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks13_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 15790550
# # reads with at least one reported alignment: 558134 (3.53%)
# # reads that failed to align: 14203012 (89.95%)
# # reads with alignments suppressed due to -m: 1029404 (6.52%)
# Reported 558134 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks13_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks13_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks13_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks13_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks13_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 14203012
# # reads with at least one reported alignment: 16978 (0.12%)
# # reads that failed to align: 12335341 (86.85%)
# # reads with alignments suppressed due to -m: 1850693 (13.03%)
# Reported 16978 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks13_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks13_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks13_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks13_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks13_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 12335341
# # reads with at least one reported alignment: 10489070 (85.03%)
# # reads that failed to align: 1400491 (11.35%)
# # reads with alignments suppressed due to -m: 445780 (3.61%)
# Reported 10489070 alignments to 1 output stream(s)
#
#
# ks14
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks14_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks14_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks14_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks14-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks14_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 7830917
# # reads with at least one reported alignment: 60581 (0.77%)
# # reads that failed to align: 7764900 (99.16%)
# # reads with alignments suppressed due to -m: 5436 (0.07%)
# Reported 60581 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks14_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks14_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks14_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks14_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks14_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 7764900
# # reads with at least one reported alignment: 224571 (2.89%)
# # reads that failed to align: 7115503 (91.64%)
# # reads with alignments suppressed due to -m: 424826 (5.47%)
# Reported 224571 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks14_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks14_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks14_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks14_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks14_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 7115503
# # reads with at least one reported alignment: 8304 (0.12%)
# # reads that failed to align: 6424687 (90.29%)
# # reads with alignments suppressed due to -m: 682512 (9.59%)
# Reported 8304 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks14_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks14_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks14_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks14_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks14_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 6424687
# # reads with at least one reported alignment: 5487440 (85.41%)
# # reads that failed to align: 769153 (11.97%)
# # reads with alignments suppressed due to -m: 168094 (2.62%)
# Reported 5487440 alignments to 1 output stream(s)
#
#
# ks15
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks15_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks15_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks15_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks15-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks15_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 11379888
# # reads with at least one reported alignment: 223276 (1.96%)
# # reads that failed to align: 11128758 (97.79%)
# # reads with alignments suppressed due to -m: 27854 (0.24%)
# Reported 223276 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks15_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks15_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks15_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks15_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks15_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 11128758
# # reads with at least one reported alignment: 405183 (3.64%)
# # reads that failed to align: 9992672 (89.79%)
# # reads with alignments suppressed due to -m: 730903 (6.57%)
# Reported 405183 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks15_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks15_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks15_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks15_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks15_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 9992672
# # reads with at least one reported alignment: 15785 (0.16%)
# # reads that failed to align: 9159500 (91.66%)
# # reads with alignments suppressed due to -m: 817387 (8.18%)
# Reported 15785 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks15_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks15_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks15_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks15_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks15_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 9159500
# # reads with at least one reported alignment: 7981550 (87.14%)
# # reads that failed to align: 964181 (10.53%)
# # reads with alignments suppressed due to -m: 213769 (2.33%)
# Reported 7981550 alignments to 1 output stream(s)
#
#
# ks16
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks16_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks16_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks16_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks16-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks16_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 15074944
# # reads with at least one reported alignment: 714220 (4.74%)
# # reads that failed to align: 14256865 (94.57%)
# # reads with alignments suppressed due to -m: 103859 (0.69%)
# Reported 714220 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks16_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks16_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks16_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks16_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks16_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 14256865
# # reads with at least one reported alignment: 514360 (3.61%)
# # reads that failed to align: 12904701 (90.52%)
# # reads with alignments suppressed due to -m: 837804 (5.88%)
# Reported 514360 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks16_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks16_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks16_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks16_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks16_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 12904701
# # reads with at least one reported alignment: 19604 (0.15%)
# # reads that failed to align: 11758641 (91.12%)
# # reads with alignments suppressed due to -m: 1126456 (8.73%)
# Reported 19604 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks16_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks16_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks16_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks16_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks16_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 11758641
# # reads with at least one reported alignment: 10189904 (86.66%)
# # reads that failed to align: 1292016 (10.99%)
# # reads with alignments suppressed due to -m: 276721 (2.35%)
# Reported 10189904 alignments to 1 output stream(s)
#
#
# ks17
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks17_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks17_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks17_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks17-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks17_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 13040388
# # reads with at least one reported alignment: 16057 (0.12%)
# # reads that failed to align: 13021708 (99.86%)
# # reads with alignments suppressed due to -m: 2623 (0.02%)
# Reported 16057 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks17_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks17_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks17_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks17_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks17_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 13021708
# # reads with at least one reported alignment: 2052694 (15.76%)
# # reads that failed to align: 5612214 (43.10%)
# # reads with alignments suppressed due to -m: 5356800 (41.14%)
# Reported 2052694 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks17_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks17_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks17_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks17_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks17_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 5612214
# # reads with at least one reported alignment: 141005 (2.51%)
# # reads that failed to align: 3846722 (68.54%)
# # reads with alignments suppressed due to -m: 1624487 (28.95%)
# Reported 141005 alignments to 1 output stream(s)
#
# ...
# # reads with alignments suppressed due to -m: 2573999 (41.27%)
# Reported 93658 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks18_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks18_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks18_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks18_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks18_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3568691
# # reads with at least one reported alignment: 2445762 (68.53%)
# # reads that failed to align: 1038566 (29.10%)
# # reads with alignments suppressed due to -m: 84363 (2.36%)
# Reported 2445762 alignments to 1 output stream(s)
#
#
# ks19
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks19_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks19_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks19_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks19-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks19_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 16810592
# # reads with at least one reported alignment: 78594 (0.47%)
# # reads that failed to align: 16725271 (99.49%)
# # reads with alignments suppressed due to -m: 6727 (0.04%)
# Reported 78594 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks19_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks19_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks19_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks19_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks19_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 16725271
# # reads with at least one reported alignment: 2102981 (12.57%)
# # reads that failed to align: 8889919 (53.15%)
# # reads with alignments suppressed due to -m: 5732371 (34.27%)
# Reported 2102981 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks19_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks19_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks19_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks19_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks19_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 8889919
# # reads with at least one reported alignment: 130522 (1.47%)
# # reads that failed to align: 5835004 (65.64%)
# # reads with alignments suppressed due to -m: 2924393 (32.90%)
# Reported 130522 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks19_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks19_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks19_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks19_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks19_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 5835004
# # reads with at least one reported alignment: 4031274 (69.09%)
# # reads that failed to align: 1657156 (28.40%)
# # reads with alignments suppressed due to -m: 146574 (2.51%)
# Reported 4031274 alignments to 1 output stream(s)
#
#
# ks20
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks20_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks20_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks20_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks20-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks20_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 11426507
# # reads with at least one reported alignment: 7901 (0.07%)
# # reads that failed to align: 11417036 (99.92%)
# # reads with alignments suppressed due to -m: 1570 (0.01%)
# Reported 7901 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks20_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks20_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks20_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks20_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks20_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 11417036
# # reads with at least one reported alignment: 1236067 (10.83%)
# # reads that failed to align: 6754351 (59.16%)
# # reads with alignments suppressed due to -m: 3426618 (30.01%)
# Reported 1236067 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks20_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks20_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks20_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks20_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks20_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 6754351
# # reads with at least one reported alignment: 124597 (1.84%)
# # reads that failed to align: 2821310 (41.77%)
# # reads with alignments suppressed due to -m: 3808444 (56.39%)
# Reported 124597 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks20_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks20_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks20_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks20_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks20_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 2821310
# # reads with at least one reported alignment: 1618933 (57.38%)
# # reads that failed to align: 1151712 (40.82%)
# # reads with alignments suppressed due to -m: 50665 (1.80%)
# Reported 1618933 alignments to 1 output stream(s)
#
#
# ks21
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks21_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks21_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks21_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks21-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks21_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 8102911
# # reads with at least one reported alignment: 16293 (0.20%)
# # reads that failed to align: 8083795 (99.76%)
# # reads with alignments suppressed due to -m: 2823 (0.03%)
# Reported 16293 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks21_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks21_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks21_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks21_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks21_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 8083795
# # reads with at least one reported alignment: 1252297 (15.49%)
# # reads that failed to align: 3202965 (39.62%)
# # reads with alignments suppressed due to -m: 3628533 (44.89%)
# Reported 1252297 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks21_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks21_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks21_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks21_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks21_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 3202965
# # reads with at least one reported alignment: 31652 (0.99%)
# # reads that failed to align: 2873018 (89.70%)
# # reads with alignments suppressed due to -m: 298295 (9.31%)
# Reported 31652 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks21_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks21_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks21_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks21_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks21_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 2873018
# # reads with at least one reported alignment: 1492743 (51.96%)
# # reads that failed to align: 1334045 (46.43%)
# # reads with alignments suppressed due to -m: 46230 (1.61%)
# Reported 1492743 alignments to 1 output stream(s)
#
#
# ks22
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks22_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks22_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks22_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/ladder/ladder /home/kazuki/^profilingdata/20160420_reanalyze/ks22-trimmed.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks22_ladder_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 6559877
# # reads with at least one reported alignment: 25521 (0.39%)
# # reads that failed to align: 6530858 (99.56%)
# # reads with alignments suppressed due to -m: 3498 (0.05%)
# Reported 25521 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks22_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks22_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks22_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/Ec_tRNA /home/kazuki/^profilingdata/20160420_reanalyze/alignments/ladder/ks22_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks22_tRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 6530858
# # reads with at least one reported alignment: 967017 (14.81%)
# # reads that failed to align: 2748518 (42.09%)
# # reads with alignments suppressed due to -m: 2815323 (43.11%)
# Reported 967017 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks22_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks22_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks22_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/rRNA_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/tRNA/ks22_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/tmpds/ks22_rRNA_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 2748518
# # reads with at least one reported alignment: 23443 (0.85%)
# # reads that failed to align: 2452111 (89.22%)
# # reads with alignments suppressed due to -m: 272964 (9.93%)
# Reported 23443 alignments to 1 output stream(s)
#
# bowtie -v 2 -y -m 1 -a --best --strata -S -p 2 --un /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks22_nomatch.fastq --max /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks22_multi.fastq --al /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks22_match.fastq /home/kazuki/^data_analysis/^scripts/ABNG_scripts/bowtie/indexes/MG1655/e_coli_MG1655 /home/kazuki/^profilingdata/20160420_reanalyze/alignments/rRNA/ks22_nomatch.fastq /home/kazuki/^profilingdata/20160420_reanalyze/alignments/chr/ks22_match.SAM 1>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt 2>> /home/kazuki/^profilingdata/20160420_reanalyze/log_bowtie_ks48.txt
# # reads processed: 2452111
# # reads with at least one reported alignment: 1408232 (57.43%)
# # reads that failed to align: 997147 (40.66%)
# # reads with alignments suppressed due to -m: 46732 (1.91%)
# Reported 1408232 alignments to 1 output stream(s)
#
# 2019-06-03 11:29:26.400353

# %%
######################################################
import csv
import pickle
from copy import deepcopy

out_path=filepath+'density/'
if not os.path.exists(out_path):
    os.makedirs(out_path)

for f in files:
    samgenmain_filename=filepath+'alignments/chr/'+f+'_match.SAM'
    f_samgenmain=open(samgenmain_filename)
    samgenmain=csv.reader(f_samgenmain,delimiter='\t')

    gff = '/home/kazuki/^data_analysis/MG1655ver2/coli.gff'

    three_mapped=three_end_mapping(samgenmain,gff)
    pickle_readcounts = out_path+f+mapping+'_readcounts.pickle'
    with open(pickle_readcounts, 'wb') as readcounts_f:
        pickle.dump(three_mapped,readcounts_f)

    three_mapped_rpm = deepcopy(three_mapped)
    readcounts_to_rpm(three_mapped_rpm[0])
    readcounts_to_rpm(three_mapped_rpm[1])
    pickle_rpm = out_path+f+mapping+'_rpm.pickle'
    with open(pickle_rpm, 'wb') as rpm_f:
        pickle.dump(three_mapped_rpm,rpm_f)
        
    density_path = out_path+f+mapping
    writecountsf(three_mapped_rpm[0],density_path+"_plus_")
    countstowig(three_mapped_rpm[0],density_path+"_plus")
    writecountsf(three_mapped_rpm[1],density_path+"_minus_")
    countstowig(three_mapped_rpm[1],density_path+"_minus")

# %%
# make a python-dictionary of RPKMs from each library
import os
import pickle
from pandas import Series, DataFrame
import pandas as pd

in_path = filepath+'density/'
out_path = filepath+'expression_2/'
if not os.path.exists(out_path):
    os.makedirs(out_path)

#########################################################################################

with open('/home/kazuki/^data_analysis/^Ecoli_Genome/Ecoli_Gene_TU.pickle','rb') as GT_f:
    Gene_TU_dict = pickle.load(GT_f)

for f in files:
    expression_dict={}
    out_pickle=out_path+f+mapping+gene_type+'_expression.pickle'
    out_csv=out_path+f+mapping+gene_type+'_expression.csv'
    readcounts_file = in_path+f+mapping+'_readcounts.pickle'
    
    with open(readcounts_file, 'rb') as rf:
        readcounts_dict = pickle.load(rf)
    plus_readcounts = readcounts_dict[0][readcounts_dict[0].keys()[0]]
    minus_readcounts = readcounts_dict[1][readcounts_dict[1].keys()[0]]
    total_read = sum(plus_readcounts)+sum(minus_readcounts)
    
    for key in Gene_TU_dict.keys():
        if key in expression_dict.keys():
            #print key +' is overlapping!!!'
            continue
    
        ########           
        if Gene_TU_dict[key][0] == '+':
            start = int(Gene_TU_dict[key][2])-1+15
            end = int(Gene_TU_dict[key][3])
        if Gene_TU_dict[key][0] == '-':
            start = int(Gene_TU_dict[key][2])-1
            end = int(Gene_TU_dict[key][3])-15            
        ########  
        
        length = end-start
        if length <= 0:
            #print key + ' is shorter than zero!!!'
            continue
        if Gene_TU_dict[key][0] == '+':
            reads = float(sum(plus_readcounts[start:end]))
        if Gene_TU_dict[key][0] == '-':
            reads = float(sum(minus_readcounts[start:end]))
        rpc = (reads/length)*3
        rpkm = (((reads/total_read)*1000000)/length)*1000
        expression_dict[key]=[]
        expression_dict[key].append(reads)
        expression_dict[key].append(rpc)
        expression_dict[key].append(rpkm)
    
    with open(out_pickle, 'wb') as op:
        pickle.dump(expression_dict,op)           
    
    rpkm_DataFrame = DataFrame.from_dict(expression_dict, orient='index')
    rpkm_DataFrame.columns = ['reads','rpc','rpkm']
    rpkm_DataFrame.to_csv(out_csv)

# %%
print "good"
# Out:
# good

# %%
######################################
########### RPKMs for 3UTR ###########
######################################

import os
import pickle
from pandas import Series, DataFrame
import pandas as pd

in_path = filepath+'density/'
out_path = filepath+'expression_3UTR/' ##################
if not os.path.exists(out_path):
    os.makedirs(out_path)

#########################################################################################

with open('/home/kazuki/^data_analysis/^Ecoli_Genome/Ecoli_Gene_TU.pickle','rb') as GT_f:
    Gene_TU_dict = pickle.load(GT_f)

for f in files:
    expression_dict={}
    out_pickle=out_path+f+mapping+gene_type+'_expression.pickle'
    out_csv=out_path+f+mapping+gene_type+'_expression.csv'
    readcounts_file = in_path+f+mapping+'_readcounts.pickle'
    
    with open(readcounts_file, 'rb') as rf:
        readcounts_dict = pickle.load(rf)
    plus_readcounts = readcounts_dict[0][readcounts_dict[0].keys()[0]]
    minus_readcounts = readcounts_dict[1][readcounts_dict[1].keys()[0]]
    total_read = sum(plus_readcounts)+sum(minus_readcounts)
    
    for key in Gene_TU_dict.keys():
        if key in expression_dict.keys():
            #print key +' is overlapping!!!'
            continue
            
            
        ########
        if type(Gene_TU_dict[key][4]) != str:
            continue

        TheLASTGene = Gene_TU_dict[key][4].split('-')[-1]
        if key != TheLASTGene:
            continue
            
        if Gene_TU_dict[key][0] == '+':
            start = int(Gene_TU_dict[key][3])-1+15
            end = int(Gene_TU_dict[key][6])
        if Gene_TU_dict[key][0] == '-':
            start = int(Gene_TU_dict[key][5])-1
            end = int(Gene_TU_dict[key][2])-15
        ########
        
        
        length = end-start
        if length <= 0:
            #print key + ' is shorter than zero!!!'
            continue
        if Gene_TU_dict[key][0] == '+':
            reads = float(sum(plus_readcounts[start:end]))
        if Gene_TU_dict[key][0] == '-':
            reads = float(sum(minus_readcounts[start:end]))
        rpc = (reads/length)*3
        rpkm = (((reads/total_read)*1000000)/length)*1000
        expression_dict[key]=[]
        expression_dict[key].append(reads)
        expression_dict[key].append(rpc)
        expression_dict[key].append(rpkm)
    
    with open(out_pickle, 'wb') as op:
        pickle.dump(expression_dict,op)           
    
    rpkm_DataFrame = DataFrame.from_dict(expression_dict, orient='index')
    rpkm_DataFrame.columns = ['reads','rpc','rpkm']
    rpkm_DataFrame.to_csv(out_csv)

# %%
print "good"
# Out:
# good
